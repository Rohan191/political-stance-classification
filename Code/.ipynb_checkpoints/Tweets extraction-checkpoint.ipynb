# %%
import numpy as np
import pandas as pd
import tweepy
import os
from tweepy import OAuthHandler
import csv
import json

# %%
consumer_key = 'JBbZgOVsUDUbIyI3LLpS39b5A'
consumer_secret = '6jZ4JViRsK302RTsc6KDfBccMS4mI4fGjHzScxOCJA7PvWFvIo'
access_token = '568966944-T4wQcwC2Lm8fh2Vcgq02vY371RRlqDYqVOxx5sgE'
access_secret = '6K7PqTYXWNx0OJoHpNuFwbEOfuXiUoZEkAUCGsSzRyvhs'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
os.chdir('../Dataset')
politicians_df = pd.read_csv('politicians.csv')
politicians = politicians_df['Twitter Handle'].values
politicians = [p.encode('ascii', 'ignore') for p in politicians]
politicians = [p.strip() for p in politicians]
print(politicians)
# Out:
# [b'ArvindKejriwal', b'CMOTamilNadu', b'Naveen_Odisha', b'rsprasad', b'arunjaitley', b'MVenkaiahNaidu', b'umasribharti', b'rajnathsingh', b'PiyushGoyal', b'PrakashJavdekar', b'SushmaSwaraj', b'sureshpprabhu', b'smritiirani', b'narendramodi', b'nitin_gadkari', b'drharshvardhan', b'nsitharaman', b'Ra_THORe', b'ChouhanShivraj', b'VasundharaBJP', b'DrJitendraSingh', b'JagadishShettar', b'mlkhattar', b'vijayrupanibjp', b'manoharparrikar', b'drramansingh', b'sarbanandsonwal', b'PemaKhanduBJP', b'myogiadityanath', b'nareshbansal14', b'BjpBiplab', b'RadhamohanBJP', b'girirajsinghbjp', b'Ramlal', b'shivprakashbjp', b'aniljaindr', b'S_MahajanLS', b'Sunil_Deodhar', b'HardeepSPuri', b'SharmaKhemchand', b'OmMathur_bjp', b'Dev_Fadnavis', b'AmitShah', b'erpankajvyas', b'tsrawatbjp', b'byadavbjp', b'ArunSinghbjp', b'KailashOnline', b'kishanreddybjp', b'ShelarAshish', b'upadhyaysbjp', b'mangalpandeybjp', b'jayantsinha', b'rammadhavbjp', b'naqvimukhtar', b'SushilModi', b'ghulamnazad', b'ABHAYCHAUTALA', b'OmarAbdullah', b'chennithala', b'Siddaramaiah4CM', b'capt_amarinder', b'VNarayanasami', b'RahulGandhi', b'SashiTharoor', b'Jairam_Ramesh', b'NitishKumar', b'iramvilaspaswan', b'vijayanpinarayi', b'ncbn', b'MamataOfficial', b'dineshgrao', b'thekjgeorge', b'PriyankKharge', b'krishnabgowda', b'SachinPilot', b'Sunil_Deodhar', b'malviyamit', b'laluprasadrjd', b'rajeshkdixit', b'ManishTewari', b'asadowaisi', b'ShuklaRajiv', b'ajaymaken', b'PChidambaram_IN', b'PavanK_Varma', b'Yashwant Sinha', b'SheilaDikshit', b'rssurjewala', b'RajBabbarMP', b'ShankersinhBapu', b'DeependerSHooda', b'harishrawatcmuk', b'virbhadrasingh', b'capt_amarinder', b'prithvrj', b'ashokgehlot51', b'sanjaynirupam', b'RajaBrar_INC', b'varungandhi80', b'TarunTewatiadyc', b'RaghusharmaINC', b'SachinKunduIYC', b'paresh_dhanani', b'jitupatwari', b'ahmedpatel', b'PawarSpeaks', b'KamalKishor_INC', b'SharadYadavMP', b'KapilSibal', b'milinddeora', b'JhaSanjay', b'MPNaveenJindal', b'AmitChavdaINC', b'dpradhanbjp', b'JitinPrasada', b'supriya_sule', b'PriyaDutt_INC', b'arjunmodhwadia', b'meira_kumar', b'priyankac19', b'sherryontopp', b'Pawankhera', b'SATAVRAJEEV', b'divyaspandana', b'RajaBrar_INC', b'tarun_gogoi', b'NabamtukiCM', b'yadavtejashwi', b'yadavakhilesh', b'JM_Scindia', b'RVikhePatil', b'shewale_rahul', b'bsmajithia', b'Dr_Cheema1', b'mssirsa', b'mieknathshinde', b'Subhash_Desai', b'GajananKirtikar', b'BhagwantMann', b'AnkitLal', b'DrSEShinde', b'AUThackeray', b'Sharmistha_GK', b'AmritaDhawan1', b'praful_patel', b'RamaAIADMK', b'mafoikprajan', b'Hariadmk', b'ptrmadurai', b'derekobrienmp', b'abhishekaitc', b'Swamy39']

# %%
def get_user_tweets(screen_name, count = 200, from_id = None):
    print('Fetching tweets for user: {0}'.format(screen_name))
    all_tweets = []
    if not from_id:
        new_tweets = api.user_timeline(screen_name = screen_name, count = count)
    else:
        new_tweets = api.user_timeline(screen_name = screen_name, count = count, max_id = from_id)
        
    all_tweets.extend(new_tweets)
    oldest = all_tweets[-1].id - 1
    
    try:
        while len(new_tweets) > 0:
            new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
            #print('Added {0} new tweets'.format(len(new_tweets)))
            all_tweets.extend(new_tweets)
            oldest = all_tweets[-1].id - 1
    except Exception as e:
        print(str(e))
        
    print('Total tweets for {0}: {1}'.format(screen_name, len(all_tweets)))
    return all_tweets

def is_retweet(tweet):
    return 'RT @' in tweet.text

# %%
a = tweets[10]
print('RT @' in a.text)
print(a.user.screen_name)
print(a.user.name)
print(a.id_str)
print(a.text)
# Out:
# True
# ArvindKejriwal
# Arvind Kejriwal
# 983891599804583936
# RT @ashu3page: अब कांग्रेस शासित पुद्दुचेरी के मुख्यमंत्री कह रहे हैं कि उपराज्यपाल उनके सरकार की फाइलों को ब्लॉक कर रही हैं। 2 दिन पहले ही…

# %%
tweets = []
for p in politicians[82:]:
    try:
        p_tweets = get_user_tweets(p, count = 200)
        tweets.extend(p_tweets)
    except Exception as e:
        print('Exception {0} while fetching tweets for {1}'.format(e, p))
# Out:
# Fetching tweets for user: b'ArvindKejriwal'
# Total tweets for b'ArvindKejriwal': 3223
# Fetching tweets for user: b'CMOTamilNadu'
# Total tweets for b'CMOTamilNadu': 1362
# Fetching tweets for user: b'Naveen_Odisha'
# Total tweets for b'Naveen_Odisha': 3225
# Fetching tweets for user: b'rsprasad'
# Total tweets for b'rsprasad': 3245
# Fetching tweets for user: b'arunjaitley'
# Total tweets for b'arunjaitley': 2482
# Fetching tweets for user: b'MVenkaiahNaidu'
# Total tweets for b'MVenkaiahNaidu': 3207
# Fetching tweets for user: b'umasribharti'
# Total tweets for b'umasribharti': 2267
# Fetching tweets for user: b'rajnathsingh'
# Total tweets for b'rajnathsingh': 3137
# Fetching tweets for user: b'PiyushGoyal'
# Total tweets for b'PiyushGoyal': 3230
# Fetching tweets for user: b'PrakashJavdekar'
# Total tweets for b'PrakashJavdekar': 3223
# Fetching tweets for user: b'SushmaSwaraj'
# Total tweets for b'SushmaSwaraj': 3209
# Fetching tweets for user: b'sureshpprabhu'
# Total tweets for b'sureshpprabhu': 3233
# Fetching tweets for user: b'smritiirani'
# Total tweets for b'smritiirani': 3223
# Fetching tweets for user: b'narendramodi'
# Total tweets for b'narendramodi': 3249
# Fetching tweets for user: b'nitin_gadkari'
# Total tweets for b'nitin_gadkari': 2097
# Fetching tweets for user: b'drharshvardhan'
# Total tweets for b'drharshvardhan': 3230
# Fetching tweets for user: b'nsitharaman'
# Total tweets for b'nsitharaman': 3248
# Fetching tweets for user: b'Ra_THORe'
# Total tweets for b'Ra_THORe': 3218
# Fetching tweets for user: b'ChouhanShivraj'
# Total tweets for b'ChouhanShivraj': 3218
# Fetching tweets for user: b'VasundharaBJP'
# Total tweets for b'VasundharaBJP': 3248
# Fetching tweets for user: b'DrJitendraSingh'
# Total tweets for b'DrJitendraSingh': 3238
# Fetching tweets for user: b'JagadishShettar'
# Total tweets for b'JagadishShettar': 1150
# Fetching tweets for user: b'mlkhattar'
# Total tweets for b'mlkhattar': 3214
# Fetching tweets for user: b'vijayrupanibjp'
# Total tweets for b'vijayrupanibjp': 3201
# Fetching tweets for user: b'manoharparrikar'
# Total tweets for b'manoharparrikar': 941
# Fetching tweets for user: b'drramansingh'
# Total tweets for b'drramansingh': 3200
# Fetching tweets for user: b'sarbanandsonwal'
# Total tweets for b'sarbanandsonwal': 3213
# Fetching tweets for user: b'PemaKhanduBJP'
# Total tweets for b'PemaKhanduBJP': 3238
# Fetching tweets for user: b'myogiadityanath'
# Total tweets for b'myogiadityanath': 3239
# Fetching tweets for user: b'nareshbansal14'
# Total tweets for b'nareshbansal14': 2076
# Fetching tweets for user: b'BjpBiplab'
# Total tweets for b'BjpBiplab': 1087
# Fetching tweets for user: b'RadhamohanBJP'
# Total tweets for b'RadhamohanBJP': 3208
# Fetching tweets for user: b'girirajsinghbjp'
# Total tweets for b'girirajsinghbjp': 3238
# Fetching tweets for user: b'Ramlal'
# Total tweets for b'Ramlal': 1497
# Fetching tweets for user: b'shivprakashbjp'
# Total tweets for b'shivprakashbjp': 774
# Fetching tweets for user: b'aniljaindr'
# Total tweets for b'aniljaindr': 3234
# Fetching tweets for user: b'S_MahajanLS'
# Total tweets for b'S_MahajanLS': 802
# Fetching tweets for user: b'Sunil_Deodhar'
# Total tweets for b'Sunil_Deodhar': 3234
# Fetching tweets for user: b'HardeepSPuri'
# Total tweets for b'HardeepSPuri': 3226
# Fetching tweets for user: b'SharmaKhemchand'
# Total tweets for b'SharmaKhemchand': 3193
# Fetching tweets for user: b'OmMathur_bjp'
# Total tweets for b'OmMathur_bjp': 3219
# Fetching tweets for user: b'Dev_Fadnavis'
# Total tweets for b'Dev_Fadnavis': 3217
# Fetching tweets for user: b'AmitShah'
# Total tweets for b'AmitShah': 3237
# Fetching tweets for user: b'erpankajvyas'
# Total tweets for b'erpankajvyas': 3214
# Fetching tweets for user: b'tsrawatbjp'
# Total tweets for b'tsrawatbjp': 3248
# Fetching tweets for user: b'byadavbjp'
# Total tweets for b'byadavbjp': 3241
# Fetching tweets for user: b'ArunSinghbjp'
# Total tweets for b'ArunSinghbjp': 1178
# Fetching tweets for user: b'KailashOnline'
# Total tweets for b'KailashOnline': 3213
# Fetching tweets for user: b'kishanreddybjp'
# Total tweets for b'kishanreddybjp': 3219
# Fetching tweets for user: b'ShelarAshish'
# Total tweets for b'ShelarAshish': 3231
# Fetching tweets for user: b'upadhyaysbjp'
# Total tweets for b'upadhyaysbjp': 3233
# Fetching tweets for user: b'mangalpandeybjp'
# Total tweets for b'mangalpandeybjp': 2379
# Fetching tweets for user: b'jayantsinha'
# Total tweets for b'jayantsinha': 3249
# Fetching tweets for user: b'rammadhavbjp'
# Total tweets for b'rammadhavbjp': 3226
# Fetching tweets for user: b'naqvimukhtar'
# Total tweets for b'naqvimukhtar': 3207
# Fetching tweets for user: b'SushilModi'
# Total tweets for b'SushilModi': 3212
# Fetching tweets for user: b'ghulamnazad'
# Total tweets for b'ghulamnazad': 1005
# Fetching tweets for user: b'ABHAYCHAUTALA'
# Total tweets for b'ABHAYCHAUTALA': 803
# Fetching tweets for user: b'OmarAbdullah'
# Total tweets for b'OmarAbdullah': 3245
# Fetching tweets for user: b'chennithala'
# Total tweets for b'chennithala': 1498
# Fetching tweets for user: b'Siddaramaiah4CM'
# Total tweets for b'Siddaramaiah4CM': 3225
# Fetching tweets for user: b'capt_amarinder'
# Total tweets for b'capt_amarinder': 2453
# Fetching tweets for user: b'VNarayanasami'
# Total tweets for b'VNarayanasami': 997
# Fetching tweets for user: b'RahulGandhi'
# Total tweets for b'RahulGandhi': 3225
# Fetching tweets for user: b'SashiTharoor'
# Exception Not authorized. while fetching tweets for b'SashiTharoor'
# Fetching tweets for user: b'Jairam_Ramesh'
# Total tweets for b'Jairam_Ramesh': 158
# Fetching tweets for user: b'NitishKumar'
# Total tweets for b'NitishKumar': 2591
# Fetching tweets for user: b'iramvilaspaswan'
# Exception list index out of range while fetching tweets for b'iramvilaspaswan'
# Fetching tweets for user: b'vijayanpinarayi'
# Total tweets for b'vijayanpinarayi': 2600
# Fetching tweets for user: b'ncbn'
# Total tweets for b'ncbn': 3225
# Fetching tweets for user: b'MamataOfficial'
# Total tweets for b'MamataOfficial': 3220
# Fetching tweets for user: b'dineshgrao'
# Total tweets for b'dineshgrao': 3207
# Fetching tweets for user: b'thekjgeorge'
# Total tweets for b'thekjgeorge': 1621
# Fetching tweets for user: b'PriyankKharge'
# Total tweets for b'PriyankKharge': 3215
# Fetching tweets for user: b'krishnabgowda'
# Total tweets for b'krishnabgowda': 1032
# Fetching tweets for user: b'SachinPilot'
# Total tweets for b'SachinPilot': 1419
# Fetching tweets for user: b'Sunil_Deodhar'
# Total tweets for b'Sunil_Deodhar': 3234
# Fetching tweets for user: b'malviyamit'
# Total tweets for b'malviyamit': 3245
# Fetching tweets for user: b'laluprasadrjd'
# Total tweets for b'laluprasadrjd': 2915
# Fetching tweets for user: b'rajeshkdixit'
# Total tweets for b'rajeshkdixit': 1814
# Fetching tweets for user: b'ManishTewari'
# Total tweets for b'ManishTewari': 3224
# Fetching tweets for user: b'asadowaisi'
# Total tweets for b'asadowaisi': 3199
# Fetching tweets for user: b'ShuklaRajiv'
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=ShuklaRajiv&count=200&max_id=648563538298957823 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19ed7a0b8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# Total tweets for b'ShuklaRajiv': 1800
# Fetching tweets for user: b'ajaymaken'
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=ajaymaken&count=200&max_id=971360296932659199 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19ef6ccf8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# Total tweets for b'ajaymaken': 200
# Fetching tweets for user: b'PChidambaram_IN'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=PChidambaram_IN&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19ef76278>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'PChidambaram_IN'
# Fetching tweets for user: b'PavanK_Varma'
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=PavanK_Varma&count=200&max_id=703765178299461631 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30a208>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# Total tweets for b'PavanK_Varma': 399
# Fetching tweets for user: b'Yashwant Sinha'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=Yashwant+Sinha&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30a748>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'Yashwant Sinha'
# Fetching tweets for user: b'SheilaDikshit'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=SheilaDikshit&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30ac18>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'SheilaDikshit'
# Fetching tweets for user: b'rssurjewala'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=rssurjewala&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f315048>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'rssurjewala'
# Fetching tweets for user: b'RajBabbarMP'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=RajBabbarMP&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f315518>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'RajBabbarMP'
# Fetching tweets for user: b'ShankersinhBapu'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=ShankersinhBapu&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f315978>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'ShankersinhBapu'
# Fetching tweets for user: b'DeependerSHooda'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=DeependerSHooda&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30a588>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'DeependerSHooda'
# Fetching tweets for user: b'harishrawatcmuk'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=harishrawatcmuk&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30a6a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'harishrawatcmuk'
# Fetching tweets for user: b'virbhadrasingh'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=virbhadrasingh&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f305d68>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'virbhadrasingh'
# Fetching tweets for user: b'capt_amarinder'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=capt_amarinder&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f3157b8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'capt_amarinder'
# Fetching tweets for user: b'prithvrj'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=prithvrj&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f315a20>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'prithvrj'
# Fetching tweets for user: b'ashokgehlot51'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=ashokgehlot51&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19ef6cc50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'ashokgehlot51'
# Fetching tweets for user: b'sanjaynirupam'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=sanjaynirupam&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f315e80>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'sanjaynirupam'
# Fetching tweets for user: b'RajaBrar_INC'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=RajaBrar_INC&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f327358>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'RajaBrar_INC'
# Fetching tweets for user: b'varungandhi80'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=varungandhi80&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f3277f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'varungandhi80'
# Fetching tweets for user: b'TarunTewatiadyc'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=TarunTewatiadyc&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f315ef0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'TarunTewatiadyc'
# Fetching tweets for user: b'RaghusharmaINC'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=RaghusharmaINC&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f3152e8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'RaghusharmaINC'
# Fetching tweets for user: b'SachinKunduIYC'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=SachinKunduIYC&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f315630>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'SachinKunduIYC'
# Fetching tweets for user: b'paresh_dhanani'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=paresh_dhanani&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f305f60>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'paresh_dhanani'
# Fetching tweets for user: b'jitupatwari'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=jitupatwari&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30a320>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'jitupatwari'
# Fetching tweets for user: b'ahmedpatel'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=ahmedpatel&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30a080>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'ahmedpatel'
# Fetching tweets for user: b'PawarSpeaks'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=PawarSpeaks&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30a1d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'PawarSpeaks'
# Fetching tweets for user: b'KamalKishor_INC'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=KamalKishor_INC&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f327240>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'KamalKishor_INC'
# Fetching tweets for user: b'SharadYadavMP'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=SharadYadavMP&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f327a20>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'SharadYadavMP'
# Fetching tweets for user: b'KapilSibal'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=KapilSibal&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f327e80>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'KapilSibal'
# Fetching tweets for user: b'milinddeora'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=milinddeora&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f327ba8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'milinddeora'
# Fetching tweets for user: b'JhaSanjay'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=JhaSanjay&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f327358>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'JhaSanjay'
# Fetching tweets for user: b'MPNaveenJindal'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=MPNaveenJindal&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30aba8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'MPNaveenJindal'
# Fetching tweets for user: b'AmitChavdaINC'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=AmitChavdaINC&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30a518>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'AmitChavdaINC'
# Fetching tweets for user: b'dpradhanbjp'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=dpradhanbjp&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30a668>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'dpradhanbjp'
# Fetching tweets for user: b'JitinPrasada'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=JitinPrasada&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f305da0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'JitinPrasada'
# Fetching tweets for user: b'supriya_sule'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=supriya_sule&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f327278>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'supriya_sule'
# Fetching tweets for user: b'PriyaDutt_INC'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=PriyaDutt_INC&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f315a90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'PriyaDutt_INC'
# Fetching tweets for user: b'arjunmodhwadia'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=arjunmodhwadia&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f315b38>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'arjunmodhwadia'
# Fetching tweets for user: b'meira_kumar'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=meira_kumar&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30d080>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'meira_kumar'
# Fetching tweets for user: b'priyankac19'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=priyankac19&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f315d30>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'priyankac19'
# Fetching tweets for user: b'sherryontopp'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=sherryontopp&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f3154e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'sherryontopp'
# Fetching tweets for user: b'Pawankhera'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=Pawankhera&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f305cc0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'Pawankhera'
# Fetching tweets for user: b'SATAVRAJEEV'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=SATAVRAJEEV&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30aa90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'SATAVRAJEEV'
# Fetching tweets for user: b'divyaspandana'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=divyaspandana&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30ab38>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'divyaspandana'
# Fetching tweets for user: b'RajaBrar_INC'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=RajaBrar_INC&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30a2b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'RajaBrar_INC'
# Fetching tweets for user: b'tarun_gogoi'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=tarun_gogoi&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f3272b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'tarun_gogoi'
# Fetching tweets for user: b'NabamtukiCM'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=NabamtukiCM&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f327860>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'NabamtukiCM'
# Fetching tweets for user: b'yadavtejashwi'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=yadavtejashwi&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30d358>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'yadavtejashwi'
# Fetching tweets for user: b'yadavakhilesh'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=yadavakhilesh&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30d780>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'yadavakhilesh'
# Fetching tweets for user: b'JM_Scindia'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=JM_Scindia&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f327c50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'JM_Scindia'
# Fetching tweets for user: b'RVikhePatil'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=RVikhePatil&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30a1d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'RVikhePatil'
# Fetching tweets for user: b'shewale_rahul'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=shewale_rahul&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30a240>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'shewale_rahul'
# Fetching tweets for user: b'bsmajithia'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=bsmajithia&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30a0b8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'bsmajithia'
# Fetching tweets for user: b'Dr_Cheema1'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=Dr_Cheema1&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19ed7a390>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'Dr_Cheema1'
# Fetching tweets for user: b'mssirsa'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=mssirsa&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f305c18>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'mssirsa'
# Fetching tweets for user: b'mieknathshinde'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=mieknathshinde&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30aef0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'mieknathshinde'
# Fetching tweets for user: b'Subhash_Desai'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=Subhash_Desai&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f315a58>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'Subhash_Desai'
# Fetching tweets for user: b'GajananKirtikar'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=GajananKirtikar&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30d828>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'GajananKirtikar'
# Fetching tweets for user: b'BhagwantMann'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=BhagwantMann&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30d9b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'BhagwantMann'
# Fetching tweets for user: b'AnkitLal'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=AnkitLal&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f3157f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'AnkitLal'
# Fetching tweets for user: b'DrSEShinde'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=DrSEShinde&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f305cc0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'DrSEShinde'
# Fetching tweets for user: b'AUThackeray'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=AUThackeray&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30ae10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'AUThackeray'
# Fetching tweets for user: b'Sharmistha_GK'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=Sharmistha_GK&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30a4e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'Sharmistha_GK'
# Fetching tweets for user: b'AmritaDhawan1'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=AmritaDhawan1&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30a9b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'AmritaDhawan1'
# Fetching tweets for user: b'praful_patel'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=praful_patel&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30aba8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'praful_patel'
# Fetching tweets for user: b'RamaAIADMK'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=RamaAIADMK&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f3279b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'RamaAIADMK'
# Fetching tweets for user: b'mafoikprajan'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=mafoikprajan&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30d9e8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'mafoikprajan'
# Fetching tweets for user: b'Hariadmk'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=Hariadmk&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30d7b8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'Hariadmk'
# Fetching tweets for user: b'ptrmadurai'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=ptrmadurai&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30df28>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'ptrmadurai'
# Fetching tweets for user: b'derekobrienmp'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=derekobrienmp&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f305c88>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'derekobrienmp'
# Fetching tweets for user: b'abhishekaitc'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=abhishekaitc&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30de10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'abhishekaitc'
# Fetching tweets for user: b'Swamy39'
# Exception Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?screen_name=Swamy39&count=200 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x19f30dac8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',)) while fetching tweets for b'Swamy39'

# %%
with open('tweets1.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(["Tweet_id", "User_Name", "User_Screen_Name", "Text"] )
    for tweet in tweets:
        if not is_retweet(tweet):
            writer.writerow([tweet.id_str, tweet.user.name, tweet.user.screen_name, tweet.text])

# %%
len(tweets)
# Out:
# 217469

# %%
politicians[82:]
# Out:
# [b'ShuklaRajiv',
#  b'ajaymaken',
#  b'PChidambaram_IN',
#  b'PavanK_Varma',
#  b'Yashwant Sinha',
#  b'SheilaDikshit',
#  b'rssurjewala',
#  b'RajBabbarMP',
#  b'ShankersinhBapu',
#  b'DeependerSHooda',
#  b'harishrawatcmuk',
#  b'virbhadrasingh',
#  b'capt_amarinder',
#  b'prithvrj',
#  b'ashokgehlot51',
#  b'sanjaynirupam',
#  b'RajaBrar_INC',
#  b'varungandhi80',
#  b'TarunTewatiadyc',
#  b'RaghusharmaINC',
#  b'SachinKunduIYC',
#  b'paresh_dhanani',
#  b'jitupatwari',
#  b'ahmedpatel',
#  b'PawarSpeaks',
#  b'KamalKishor_INC',
#  b'SharadYadavMP',
#  b'KapilSibal',
#  b'milinddeora',
#  b'JhaSanjay',
#  b'MPNaveenJindal',
#  b'AmitChavdaINC',
#  b'dpradhanbjp',
#  b'JitinPrasada',
#  b'supriya_sule',
#  b'PriyaDutt_INC',
#  b'arjunmodhwadia',
#  b'meira_kumar',
#  b'priyankac19',
#  b'sherryontopp',
#  b'Pawankhera',
#  b'SATAVRAJEEV',
#  b'divyaspandana',
#  b'RajaBrar_INC',
#  b'tarun_gogoi',
#  b'NabamtukiCM',
#  b'yadavtejashwi',
#  b'yadavakhilesh',
#  b'JM_Scindia',
#  b'RVikhePatil',
#  b'shewale_rahul',
#  b'bsmajithia',
#  b'Dr_Cheema1',
#  b'mssirsa',
#  b'mieknathshinde',
#  b'Subhash_Desai',
#  b'GajananKirtikar',
#  b'BhagwantMann',
#  b'AnkitLal',
#  b'DrSEShinde',
#  b'AUThackeray',
#  b'Sharmistha_GK',
#  b'AmritaDhawan1',
#  b'praful_patel',
#  b'RamaAIADMK',
#  b'mafoikprajan',
#  b'Hariadmk',
#  b'ptrmadurai',
#  b'derekobrienmp',
#  b'abhishekaitc',
#  b'Swamy39']
